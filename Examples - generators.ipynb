# %%
from ats import logger
logger.setup('INFO')

from ats.dataset_generators import HumiTempDatasetGenerator

# Inizialize
generator = HumiTempDatasetGenerator()

# --- Test generate_test_dataset ---

test_dataset = generator.generate( 
    n_series = 13,
    effects = [],
    anomalies = ['spike_uv', 'step_uv', 'step_mv', 'step_mv'],
    time_span = '90D',
    max_anomalies_per_series = 4,
    anomalies_ratio = 1

)
generator.plot_dataset(test_dataset)
# Out:
# [INFO] ats.dataset_generators: Generating datest with max 4 anomalies per series and with a 100 % of series with anomalies.
# [INFO] ats.dataset_generators: Generated dataset 1 with effects: [] and anomalies: ['step_uv', 'spike_uv']
# [INFO] ats.dataset_generators: Generated dataset 2 with effects: [] and anomalies: ['step_mv']
# [INFO] ats.dataset_generators: Generated dataset 3 with effects: [] and anomalies: ['step_uv', 'step_mv']
# [INFO] ats.dataset_generators: Generated dataset 4 with effects: [] and anomalies: ['step_mv', 'spike_uv', 'step_mv']
# [INFO] ats.dataset_generators: Generated dataset 5 with effects: [] and anomalies: ['step_mv', 'step_uv']
# [INFO] ats.dataset_generators: Generated dataset 6 with effects: [] and anomalies: ['step_mv', 'spike_uv', 'step_mv', 'step_uv']
# [INFO] ats.dataset_generators: Generated dataset 7 with effects: [] and anomalies: ['step_mv', 'step_uv', 'spike_uv', 'step_mv']
# [INFO] ats.dataset_generators: Generated dataset 8 with effects: [] and anomalies: ['step_mv', 'spike_uv', 'step_uv']
# [INFO] ats.dataset_generators: Generated dataset 9 with effects: [] and anomalies: ['step_mv']
# [INFO] ats.dataset_generators: Generated dataset 10 with effects: [] and anomalies: ['step_mv', 'spike_uv', 'step_uv']
# [INFO] ats.dataset_generators: Generated dataset 11 with effects: [] and anomalies: ['step_uv', 'spike_uv', 'step_mv']
# [INFO] ats.dataset_generators: Generated dataset 12 with effects: [] and anomalies: ['step_mv', 'spike_uv']
# [INFO] ats.dataset_generators: Generated dataset 13 with effects: [] and anomalies: ['step_uv', 'step_mv']
# [None, None, None, None, None, None, None, None, None, None, None, None, None]
